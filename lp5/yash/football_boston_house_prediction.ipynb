# %%
import numpy as np

# %%
import pandas as pd

# %%
from tensorflow.keras.datasets import boston_housing

# %%
(x_train,y_train),(x_test,y_test)=boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(64,activation='relu',input_shape=(x_train.shape[1],)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(Dense(32,activation='relu'))

# %%
model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history=model.fit(x_train,y_train,epochs=50,batch_size=16,validation_split=0.2,verbose=1)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 537.6359 - mae: 21.2617 - val_loss: 565.6882 - val_mae: 22.0102
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 457.2994 - mae: 19.4191 - val_loss: 465.7009 - val_mae: 19.7409
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 340.5095 - mae: 16.4216 - val_loss: 316.1423 - val_mae: 15.8370
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 195.4034 - mae: 11.7448 - val_loss: 149.5101 - val_mae: 9.8019
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 83.7075 - mae: 7.1618 - val_loss: 74.2614 - val_mae: 6.5052
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 51.3045 - mae: 5.2513 - val_loss: 52.0199 - val_mae: 5.3948
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 39.8171 - mae: 4.4598 - val_loss: 39.7029 - val_mae: 4.6751
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 32.5344 - mae: 3.9689 - val_loss: 34.6478 - val_mae: 4.3032
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28.7025 - mae: 3.6727 - val_loss: 31.4695 - val_mae: 4.0829
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 26.3469 - mae: 3.5104 - val_loss: 27.9775 - val_mae: 3.9126
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 24.2581 - mae: 3.4341 - val_loss: 25.1236 - val_mae: 3.8258
# Epoch 12/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.4377 - mae: 3.3737 - val_loss: 22.9569 - val_mae: 3.6869
# Epoch 13/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.7859 - mae: 3.1931 - val_loss: 22.4647 - val_mae: 3.5939
# Epoch 14/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.8933 - mae: 3.1110 - val_loss: 21.5855 - val_mae: 3.5372
# Epoch 15/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.9407 - mae: 3.0144 - val_loss: 20.2454 - val_mae: 3.4313
# Epoch 16/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9756 - mae: 2.9641 - val_loss: 19.3230 - val_mae: 3.3704
# Epoch 17/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.1550 - mae: 2.8872 - val_loss: 18.5899 - val_mae: 3.3010
# Epoch 18/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.3470 - mae: 2.8257 - val_loss: 18.2790 - val_mae: 3.2929
# Epoch 19/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.8540 - mae: 2.7851 - val_loss: 17.4211 - val_mae: 3.1924
# Epoch 20/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1762 - mae: 2.7122 - val_loss: 16.7391 - val_mae: 3.1047
# Epoch 21/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.8092 - mae: 2.6334 - val_loss: 16.3961 - val_mae: 3.0807
# Epoch 22/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.1543 - mae: 2.5985 - val_loss: 15.9075 - val_mae: 3.0202
# Epoch 23/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.7838 - mae: 2.6086 - val_loss: 15.6684 - val_mae: 2.9886
# Epoch 24/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4554 - mae: 2.5248 - val_loss: 14.9348 - val_mae: 2.8797
# Epoch 25/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.8772 - mae: 2.4954 - val_loss: 15.0356 - val_mae: 2.9133
# Epoch 26/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.5796 - mae: 2.4613 - val_loss: 14.4993 - val_mae: 2.8539
# Epoch 27/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.2330 - mae: 2.4286 - val_loss: 14.3131 - val_mae: 2.8283
# Epoch 28/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.9639 - mae: 2.3881 - val_loss: 14.1041 - val_mae: 2.7835
# Epoch 29/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.5333 - mae: 2.3464 - val_loss: 13.9642 - val_mae: 2.7925
# Epoch 30/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2328 - mae: 2.3381 - val_loss: 13.4992 - val_mae: 2.7063
# Epoch 31/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9775 - mae: 2.2931 - val_loss: 13.3389 - val_mae: 2.7155
# Epoch 32/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7594 - mae: 2.2750 - val_loss: 13.4162 - val_mae: 2.7059
# Epoch 33/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.4742 - mae: 2.2582 - val_loss: 13.2991 - val_mae: 2.6705
# Epoch 34/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.4014 - mae: 2.2269 - val_loss: 13.2295 - val_mae: 2.6944
# Epoch 35/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.1249 - mae: 2.2115 - val_loss: 13.4950 - val_mae: 2.6734
# Epoch 36/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9553 - mae: 2.1946 - val_loss: 13.3988 - val_mae: 2.6640
# Epoch 37/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0347 - mae: 2.1804 - val_loss: 13.1937 - val_mae: 2.6220
# Epoch 38/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8280 - mae: 2.1678 - val_loss: 13.3719 - val_mae: 2.6314
# Epoch 39/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5528 - mae: 2.1581 - val_loss: 13.3990 - val_mae: 2.6359
# Epoch 40/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4611 - mae: 2.1438 - val_loss: 13.1556 - val_mae: 2.6250
# Epoch 41/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3302 - mae: 2.0983 - val_loss: 13.4105 - val_mae: 2.6320
# Epoch 42/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1424 - mae: 2.0953 - val_loss: 13.3068 - val_mae: 2.5704
# Epoch 43/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0820 - mae: 2.1166 - val_loss: 13.4458 - val_mae: 2.5997
# Epoch 44/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9775 - mae: 2.0858 - val_loss: 13.3279 - val_mae: 2.5677
# Epoch 45/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7656 - mae: 2.0424 - val_loss: 13.4419 - val_mae: 2.5813
# Epoch 46/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7188 - mae: 2.0515 - val_loss: 13.6641 - val_mae: 2.5842
# Epoch 47/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6027 - mae: 2.0709 - val_loss: 13.4426 - val_mae: 2.5675
# Epoch 48/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5172 - mae: 2.0264 - val_loss: 13.3455 - val_mae: 2.5517
# Epoch 49/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3753 - mae: 2.0059 - val_loss: 13.2248 - val_mae: 2.5366
# Epoch 50/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4141 - mae: 1.9828 - val_loss: 13.2608 - val_mae: 2.5224

# %%
y_pred=model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
print(y_pred)
# Out:
# [[ 9.407536 ]
#  [17.017456 ]
#  [21.361364 ]
#  [31.261284 ]
#  [25.637043 ]
#  [18.45346  ]
#  [26.57939  ]
#  [21.2947   ]
#  [19.45394  ]
#  [21.554142 ]
#  [19.743935 ]
#  [17.103588 ]
#  [15.352645 ]
#  [42.160526 ]
#  [18.728909 ]
#  [18.878387 ]
#  [27.305004 ]
#  [20.299572 ]
#  [18.668737 ]
#  [36.182667 ]
#  [11.646071 ]
#  [15.709146 ]
#  [20.042912 ]
#  [14.872071 ]
#  [20.512676 ]
#  [24.008224 ]
#  [30.912779 ]
#  [29.722876 ]
#  [11.375042 ]
#  [20.71611  ]
#  [18.882458 ]
#  [15.141031 ]
#  [33.902824 ]
#  [25.52985  ]
#  [17.601902 ]
#  [ 8.529317 ]
#  [14.826338 ]
#  [17.67011  ]
#  [20.815863 ]
#  [25.597366 ]
#  [30.025429 ]
#  [28.531275 ]
#  [14.277318 ]
#  [41.352375 ]
#  [31.155603 ]
#  [24.720747 ]
#  [25.834162 ]
#  [15.348188 ]
#  [22.578196 ]
#  [21.523705 ]
#  [33.313896 ]
#  [17.958752 ]
#  [12.482141 ]
#  [16.371704 ]
#  [33.931705 ]
#  [28.394169 ]
#  [12.606833 ]
#  [48.22454  ]
#  [34.82169  ]
#  [23.841558 ]
#  [24.095964 ]
#  [17.230043 ]
#  [14.510642 ]
#  [17.270008 ]
#  [23.492668 ]
#  [21.631824 ]
#  [13.5476885]
#  [21.552486 ]
#  [13.089227 ]
#  [ 8.240991 ]
#  [36.087814 ]
#  [28.93979  ]
#  [23.407877 ]
#  [14.779349 ]
#  [24.833315 ]
#  [17.674828 ]
#  [19.652504 ]
#  [22.9762   ]
#  [34.571533 ]
#  [10.22712  ]
#  [19.048534 ]
#  [37.948036 ]
#  [14.434666 ]
#  [14.066913 ]
#  [16.586224 ]
#  [18.169424 ]
#  [19.661043 ]
#  [20.506313 ]
#  [21.730179 ]
#  [30.175167 ]
#  [19.803032 ]
#  [19.914808 ]
#  [25.09321  ]
#  [40.44119  ]
#  [35.287735 ]
#  [19.191093 ]
#  [35.78447  ]
#  [52.586895 ]
#  [27.304668 ]
#  [45.0865   ]
#  [32.51879  ]
#  [20.419865 ]]

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mae=mean_absolute_error(y_test,y_pred)

# %%
print(mse,mae)
# Out:
# 24.799733826884147 3.1800510873981556

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
